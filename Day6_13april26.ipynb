# %%
x = 10
floor_division = x // 3 
print(floor_division)
# Out:
# 3

# %%
x = 10
x += 5
print(x)
x -= 3
print(x)
x *= 2
print(x)    
x /= 4
print(x)
# Out:
# 15
# 12
# 24
# 6.0

# %%
'durgesh' <= 'dwarf'
print('durgesh' <= 'dwarf')
# Out:
# True

# %%
A = 65
a = 97
A > a
print('A > a:', A > a)
# Out:
# A > a: False

# %%
x > 5 and x < 1
print(x > 5 and x < 1)
# Out:
# False

# %%
x > 5 or x < 1
print(x > 5 or x < 1)
# Out:
# True

# %%
not x > 5
print(not x > 5)
# Out:
# False

# %%
x = [2, 3, 4]
y = [2, 3, 4]
z = x
print(x is y)
print(x == y)
print(x is z)
# Out:
# False
# True
# True

# %%
x = ['Apple', 'Banana', 'Mango']
print('Mango' in x)
# Out:
# True

# %%
x = 5
if  x > 10:
    print('Yes')

elif x > 20:
    print('No')

else:
    print('out')
# Out:
# out

# %%
x =5 
if (x > 100):
    if (x/2==0):
        print('Even') 
    else:
        print('Odd')
else:
    print('Value is less than 100')
# Out:
# Value is less than 100
