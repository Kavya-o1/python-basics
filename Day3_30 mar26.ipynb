# %%
stud =["kavya","ganesh","durgesh","atharva"]
un_stud = set(stud)
print(un_stud)
un_stud = list(un_stud)
print(un_stud)
# Out:
# {'ganesh', 'atharva', 'kavya', 'durgesh'}
# ['ganesh', 'atharva', 'kavya', 'durgesh']

# %%
x = "250"
print(x)
print(type(x))
# Out:
# 250
# <class 'str'>

# %%
x = "99"
print(x)
print(type(x))

x_float = float(x)
print(x_float)
print(type(x_float))

x_bool = bool(x)
print(x_bool)
print(type(x_bool))

x_list = list(x)
print(x_list)
print(type(x_list))
# Out:
# 99
# <class 'str'>
# 99.0
# <class 'float'>
# True
# <class 'bool'>
# ['9', '9']
# <class 'list'>

# %%
x ="45.67"
x_float = float(x)
print(x_float)
print(type(x_float))

x_int = int(x_float)
print(x_int)
print(type(x_int))
# Out:
# 45.67
# <class 'float'>
# 45
# <class 'int'>

# %%
x = 45.67
x_int = int(x)
print(x_int)
print(type(x_int))

y = False
print(type(y))
y

y_int = int(y)  
print(y_int)
print(type(y_int))
# Out:
# 45
# <class 'int'>
# <class 'bool'>
# 0
# <class 'int'>

# %%
x = ("10", "20", "30")
x_list = list(x)
print(x_list)
print(type(x_list))
# Out:
# ['10', '20', '30']
# <class 'list'>

# %%
x =("1", "2", "3","4", "5")
print(f"First element: {x[0]}")
print(f"Last element: {x[-1]}")
print(f"Length of list: {len(x)}")
# Out:
# First element: 1
# Last element: 5
# Length of list: 5

# %%
s ="MachineLearning"
print(f"First 7 characters: {s[:7]}")
print(f"Last 5 characters: {s[-5:]}")
# Out:
# First 7 characters: Machine
# Last 5 characters: rning

# %%
t[1] = 50
except TypeError as e:
    print(f"Error: {e}")
    print("Tuples are immutable, cannot modify elements.")
# Out:
#   Cell In[7], line 2
#     except TypeError as e:
#     ^
# SyntaxError: invalid syntax

# %%
string = "python"
char_list = list(string)
print(char_list)
# Out:
# ['p', 'y', 't', 'h', 'o', 'n']

# %%
nums = [5, 10, 15, 20]
nums.append(25)
nums.remove(10)
print(nums)
# Out:
# [5, 15, 20, 25]
